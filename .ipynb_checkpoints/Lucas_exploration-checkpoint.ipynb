# %%
import pandas as pd
import numpy as np
pd.set_option('display.max_rows', 30)
pd.set_option('display.max_columns', None)
pd.set_option('display.width', None)
pd.set_option('display.max_colwidth', None)

# %%
dir_folder = 'C:\\Users\\Lucas\\Documents\\GitHub\\'
df_w = pd.read_csv(dir_folder + '\\2. Weather data\\training_set_weather_data.csv')
df_w
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-7-cc40b6f3de9f> in <module>
#       1 dir_folder = 'C:\\Users\\Lucas\\Documents\\GitHub\\'
# ----> 2 df_w = pd.read_csv(dir_folder + '\\2. Weather data\\training_set_weather_data.csv')
#       3 df_w
#
# ...

# %%
df_a = pd.read_excel('C:\\Data\\Hackathon\\1. AC characteristics\\ACchar.xlsx', sheet_name='test')
df_a
# Out:
#            Date Completed Manufacturer                  A320-100  \
# 0     2018-07-03 00:00:00   Acro Sport                Acro Sport
# 1     2018-06-01 00:00:00   Acro Sport             Acro Sport II
# 2     2018-07-03 00:00:00   Acro Sport                    Cougar
# 3     2018-07-03 00:00:00   Acro Sport                Junior Ace
# 4     2018-07-03 00:00:00   Acro Sport                 Super Ace
# ...                   ...          ...                       ...
# 2759                  NaN         Zlin                 Zlin Z-50
# 2760                  NaN         Zlin        Zlin Z-526 Akrobat
# 2761                  NaN         Zlin  Zlin Z-526 Trener Master
# 2762                  NaN         Zlin                Zlin Z-626
# 2763                  tbd         Zlin      Zlin Z-726 Universal
#
#      Physical Class (Engine) # Engines       AAC       ADG  TDG  \
# 0                     Piston         1         A         I   1A
# ...

# %%
#df_apt_geo = pd.read_csv("C:\\Data\\Hackathon\\0. Airport data\\geographic_data.csv")
df_apt_geo['Lat_runway'].unique()
# Out:
# array([54.75530667, 54.75712   , 54.76117333, 54.76149333])

# %%
df_apt_time = pd.read_csv('C:\\Data\\Hackathon\\0. Airport data\\training_set_airport_data.csv')
df_apt_time
# Out:
#          Flight Datetime       Aircraft Model              AOBT  \
# 0          1/1/2015 6:00    B737-800 WINGLETS     1/1/2015 5:56
# 1          1/1/2015 6:10         A320-100/200     1/1/2015 6:08
# 2          1/1/2015 6:15         A320-100/200     1/1/2015 6:08
# 3          1/1/2015 6:20         A320-100/200     1/1/2015 6:24
# 4          1/1/2015 6:20                 A319     1/1/2015 6:14
# ...                  ...                  ...               ...
# 543808  12/31/2018 21:15             A350-900  12/31/2018 21:02
# 543809  12/31/2018 21:30             B787-900  12/31/2018 21:24
# 543810  12/31/2018 21:50             A330-200  12/31/2018 22:27
# 543811  12/31/2018 22:10  B787-800 Dreamliner  12/31/2018 22:09
# 543812  12/31/2018 23:55             B787-900  12/31/2018 23:58
#
#                     ATOT      Stand    Runway
# 0          1/1/2015 6:05   STAND_62  RUNWAY_4
# 1          1/1/2015 6:18  STAND_153  RUNWAY_4
# 2          1/1/2015 6:19   STAND_44  RUNWAY_2
# ...

# %%
# Out:
#          Flight Datetime       Aircraft Model              AOBT  \
# 0          1/1/2015 6:00    B737-800 WINGLETS     1/1/2015 5:56
# 1          1/1/2015 6:10         A320-100/200     1/1/2015 6:08
# 2          1/1/2015 6:15         A320-100/200     1/1/2015 6:08
# 3          1/1/2015 6:20         A320-100/200     1/1/2015 6:24
# 4          1/1/2015 6:20                 A319     1/1/2015 6:14
# ...                  ...                  ...               ...
# 543808  12/31/2018 21:15             A350-900  12/31/2018 21:02
# 543809  12/31/2018 21:30             B787-900  12/31/2018 21:24
# 543810  12/31/2018 21:50             A330-200  12/31/2018 22:27
# 543811  12/31/2018 22:10  B787-800 Dreamliner  12/31/2018 22:09
# 543812  12/31/2018 23:55             B787-900  12/31/2018 23:58
#
#                     ATOT      Stand    Runway
# 0          1/1/2015 6:05   STAND_62  RUNWAY_4
# 1          1/1/2015 6:18  STAND_153  RUNWAY_4
# 2          1/1/2015 6:19   STAND_44  RUNWAY_2
# ...
